# %%
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

try:
    os.chdir("../../DevSurveyInsights/scripts")
except FileNotFoundError:
    print("You are already in the correct directory.")
